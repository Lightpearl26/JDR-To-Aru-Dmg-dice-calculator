# %%
from libs.character import Character
# Out:
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: Logger initialized
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.con + user.wis' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '(user.con + user.wis) / 20 + diceratio(user.int, 10)' compilated to template '{0} / {1} + {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.hp / 10' compilated to template '{0} / {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + (user.hp / 10) + diceratio(user.sur, 2)' compilated to template '{0} + {1} + {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 20)' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 10) - diceratio(target.wis, 10)' compilated to template '{0} + {1} - {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.int / 10' compilated to template '{0} / {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + diceratio(user.cha, 20) - (user.int / 10) - diceratio(target.cha, 20)' compilated to template '{0} + {1} - {2} - {3}' with 4 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '' compilated to template '' with 0 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '' compilated to template '' with 0 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'diceattack(user.int, 10, target.con, 10)' compilated to template '{0}' with 1 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.wis / 20' compilated to template '{0} / {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '(user.wis / 20) + diceratio(user.int, 20)' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '20 + diceratio(user.int, 30) - diceratio(target.wis, 10)' compilated to template '{0} + {1} - {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '100 - user.mental_health' compilated to template '{0} - {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 10) + (100 - user.mental_health) / 10' compilated to template '{0} + {1} + {2} / {3}' with 4 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '100 - user.mental_health' compilated to template '{0} - {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + diceratio(user.int, 5) + (100 - user.mental_health) / 20' compilated to template '{0} + {1} + {2} / {3}' with 4 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 20)' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'diceratio(user.int, 30) - diceratio(target.wis, 10)' compilated to template '{0} - {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.wis / 10' compilated to template '{0} / {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '(user.wis / 10) + diceratio(user.int, 10)' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'diceratio(user.str, 10) + diceratio(user.int, 10) - diceratio(target.con, 10)' compilated to template '{0} + {1} - {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + diceratio(user.int, 10) - diceratio(target.wis, 10)' compilated to template '{0} + {1} - {2}' with 3 placeholders.
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
groupe = [
    alistair := Character.from_name("Alistair"),
    heilari := Character.from_name("Heilari"),
    hella := Character.from_name("Hella"),
    saru := Character.from_name("Saru"),
    dexter := Character.from_name("Dexter")
]
# Out:
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Stats] Created with values: str=105, dex=55, con=110, int=30, wis=100, cha=20, per=20, agi=60, luc=30, sur=50, stamina=100, mental_health=100, drug_health=100
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [StatsModifiers] Created with values: hp=0, str=0, dex=0, con=0, int=0, wis=0, cha=0, per=0, agi=0, luc=0, sur=0, stamina=-20, mental_health=-20, drug_health=-10
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.wis / 10' compilated to template '{0} / {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '(user.wis / 10) + diceratio(user.int, 10)' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'diceratio(user.str, 10) + diceratio(user.int, 10) - diceratio(target.con, 10)' compilated to template '{0} + {1} - {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Inventory] Inventory created with items: {'Monster': 1, 'Matraque': 1}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] Created character 'Alistair' with stats: {'str': 105, 'dex': 55, 'con': 110, 'int': 30, 'wis': 100, 'cha': 20, 'per': 20, 'agi': 60, 'luc': 30, 'sur': 50, 'stamina': 100, 'mental_health': 100, 'drug_health': 100} and modifiers: {'hp': 0, 'str': 0, 'dex': 0, 'con': 0, 'int': 0, 'wis': 0, 'cha': 0, 'per': 0, 'agi': 0, 'luc': 0, 'sur': 0, 'stamina': -20, 'mental_health': -20, 'drug_health': -10}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Stats] Created with values: str=25, dex=95, con=40, int=80, wis=65, cha=60, per=50, agi=40, luc=50, sur=75, stamina=100, mental_health=100, drug_health=100
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [StatsModifiers] Created with values: hp=0, str=0, dex=0, con=0, int=-10, wis=0, cha=2, per=0, agi=30, luc=0, sur=0, stamina=-55, mental_health=0, drug_health=0
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.hp / 10' compilated to template '{0} / {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + (user.hp / 10) + diceratio(user.sur, 2)' compilated to template '{0} + {1} + {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 20)' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + diceratio(user.int, 10) - diceratio(target.wis, 10)' compilated to template '{0} + {1} - {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Inventory] Inventory created with items: {'Monster': 1, 'Trousse a pharmacie': 1, 'Photos centre ville': 1, 'Dague de Judas': 1, 'Conserves': 2, 'Enceinte': 1, 'Talkie Walkie': 1, 'Carte numerique Charles': 1, 'Nokia3310': 1, 'Béatrice': 1, 'Barres de chocolat': 208}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] Created character 'Heilari' with stats: {'str': 25, 'dex': 95, 'con': 40, 'int': 80, 'wis': 65, 'cha': 60, 'per': 50, 'agi': 40, 'luc': 50, 'sur': 75, 'stamina': 100, 'mental_health': 100, 'drug_health': 100} and modifiers: {'hp': 0, 'str': 0, 'dex': 0, 'con': 0, 'int': -10, 'wis': 0, 'cha': 2, 'per': 0, 'agi': 30, 'luc': 0, 'sur': 0, 'stamina': -55, 'mental_health': 0, 'drug_health': 0}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Stats] Created with values: str=75, dex=55, con=70, int=30, wis=50, cha=60, per=50, agi=60, luc=50, sur=80, stamina=100, mental_health=100, drug_health=100
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [StatsModifiers] Created with values: hp=-12, str=0, dex=0, con=0, int=0, wis=0, cha=0, per=0, agi=0, luc=0, sur=0, stamina=-15, mental_health=-20, drug_health=0
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '100 - user.mental_health' compilated to template '{0} - {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 10) + (100 - user.mental_health) / 10' compilated to template '{0} + {1} + {2} / {3}' with 4 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '100 - user.mental_health' compilated to template '{0} - {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + diceratio(user.int, 5) + (100 - user.mental_health) / 20' compilated to template '{0} + {1} + {2} / {3}' with 4 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.int / 10' compilated to template '{0} / {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '5 + diceratio(user.cha, 20) - (user.int / 10) - diceratio(target.cha, 20)' compilated to template '{0} + {1} - {2} - {3}' with 4 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Inventory] Inventory created with items: {'Tuyau en metal': 1, 'Monster': 1, 'Bague reve bronze': 1, 'Pieces S.O.Nathanaël': 1, 'Contrat avec Dexter': 1}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] Created character 'Hella' with stats: {'str': 75, 'dex': 55, 'con': 70, 'int': 30, 'wis': 50, 'cha': 60, 'per': 50, 'agi': 60, 'luc': 50, 'sur': 80, 'stamina': 100, 'mental_health': 100, 'drug_health': 100} and modifiers: {'hp': -12, 'str': 0, 'dex': 0, 'con': 0, 'int': 0, 'wis': 0, 'cha': 0, 'per': 0, 'agi': 0, 'luc': 0, 'sur': 0, 'stamina': -15, 'mental_health': -20, 'drug_health': 0}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Stats] Created with values: str=40, dex=95, con=40, int=80, wis=75, cha=40, per=65, agi=30, luc=70, sur=50, stamina=100, mental_health=100, drug_health=100
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [StatsModifiers] Created with values: hp=0, str=0, dex=0, con=0, int=0, wis=0, cha=0, per=0, agi=0, luc=0, sur=0, stamina=-10, mental_health=-20, drug_health=0
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 10) - diceratio(target.wis, 10)' compilated to template '{0} + {1} - {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'diceattack(user.int, 10, target.con, 10)' compilated to template '{0}' with 1 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Inventory] Inventory created with items: {'Monster': 1, 'Photos centre ville': 1, 'Petit couteau': 1, "Rubik's Cube": 1, 'Talkie Walkie': 1, 'Pieces S.O.Nathanaël': 5, 'Bague reve bronze': 2, 'Arbalete poignet': 1, 'Sceptre du pouvoir': 1}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] Created character 'Saru' with stats: {'str': 40, 'dex': 95, 'con': 40, 'int': 80, 'wis': 75, 'cha': 40, 'per': 65, 'agi': 30, 'luc': 70, 'sur': 50, 'stamina': 100, 'mental_health': 100, 'drug_health': 100} and modifiers: {'hp': 0, 'str': 0, 'dex': 0, 'con': 0, 'int': 0, 'wis': 0, 'cha': 0, 'per': 0, 'agi': 0, 'luc': 0, 'sur': 0, 'stamina': -10, 'mental_health': -20, 'drug_health': 0}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Stats] Created with values: str=50, dex=70, con=50, int=150, wis=50, cha=60, per=60, agi=20, luc=80, sur=80, stamina=100, mental_health=100, drug_health=100
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [StatsModifiers] Created with values: hp=-15, str=0, dex=0, con=0, int=0, wis=0, cha=0, per=0, agi=0, luc=0, sur=0, stamina=-60, mental_health=-30, drug_health=0
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '10 + diceratio(user.int, 20)' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula 'user.con + user.wis' compilated to template '{0} + {1}' with 2 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Formula] Formula '(user.con + user.wis) / 20 + diceratio(user.int, 10)' compilated to template '{0} / {1} + {2}' with 3 placeholders.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Inventory] Inventory created with items: {'Monster': 1, '3DS': 1, 'Kinder Maxi': 1, 'Ventoline': 1, 'Parapluie Mickey': 1}
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] Created character 'Dexter' with stats: {'str': 50, 'dex': 70, 'con': 50, 'int': 150, 'wis': 50, 'cha': 60, 'per': 60, 'agi': 20, 'luc': 80, 'sur': 80, 'stamina': 100, 'mental_health': 100, 'drug_health': 100} and modifiers: {'hp': -15, 'str': 0, 'dex': 0, 'con': 0, 'int': 0, 'wis': 0, 'cha': 0, 'per': 0, 'agi': 0, 'luc': 0, 'sur': 0, 'stamina': -60, 'mental_health': -30, 'drug_health': 0}

# %%
for c in groupe:
    c.create_sheet()
# Out:
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'hp': 31
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'stamina': 80
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'hp': 31
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'stamina': 80
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'str': 120
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'dex': 55
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'con': 110
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'wis': 100
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'int': 30
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'cha': 20
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'per': 20
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'agi': 60
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'luc': 30
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Matraque'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Current value of stat 'sur': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Alistair'> Character sheet created.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'hp': 20
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'stamina': 45
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'hp': 20
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'stamina': 45
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'str': 30
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'dex': 95
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'con': 40
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'wis': 65
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'int': 70
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'cha': 102
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'per': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'agi': 70
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'luc': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Trousse a pharmacie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Dague de Judas'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Conserves'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Enceinte'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Carte numerique Charles'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Nokia3310'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Béatrice'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Barres de chocolat'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Current value of stat 'sur': 95
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Heilari'> Character sheet created.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'hp': 10
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'stamina': 85
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'hp': 10
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'stamina': 85
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'str': 95
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'dex': 55
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'con': 70
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'wis': 51
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'int': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'cha': 60
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'per': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'agi': 60
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'luc': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Tuyau en métal'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Contrat avec Dexter'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Current value of stat 'sur': 80
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Hella'> Character sheet created.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'hp': 21
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'stamina': 90
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'hp': 21
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'stamina': 90
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'str': 45
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'dex': 105
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'con': 40
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'wis': 80
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'int': 130
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'cha': 40
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'per': 65
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'agi': 0
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'luc': 70
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Photos centre ville'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Petit couteau'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Rubik's Cube'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Talkie Walkie'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Pièces S.O.Nathanaël'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Bague reve bronze'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Arbalete poignez'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Sceptre du pouvoir'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Current value of stat 'sur': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Saru'> Character sheet created.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'hp': 5
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'stamina': 40
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'hp': 5
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'stamina': 40
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'str': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'dex': 70
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'con': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'wis': 50
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'int': 150
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'cha': 60
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'per': 60
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'agi': 20
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'luc': 80
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Monster'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'3DS'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Kinder Maxi'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Ventoline'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Item] <'Parapluie Mickey'> Item loaded.
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Current value of stat 'sur': 80
# [ Debug ][ MainThread ][ Sun Dec 21 04:37:08 2025 ]: [Character] <'Dexter'> Character sheet created.

# %%
others = [
    Character.from_name("Julie"),
    Character.from_name("Dummy"),
    Character.from_name("Mage"),
]
for c in others:
    c.create_sheet()
# Out:
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
